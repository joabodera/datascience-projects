# %%
pip install azureml
# Out:
# Collecting azureml
#   Downloading azureml-0.2.7-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.9/site-packages (from azureml) (2.8.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from azureml) (2.26.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from azureml) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->azureml) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->azureml) (1.24.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil->azureml) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->azureml) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->azureml) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->azureml) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests->azureml) (2.0.4)
# Installing collected packages: azureml
# Successfully installed azureml-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-core
# Out:
# Collecting azureml-core
#   Downloading azureml_core-1.56.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 1.5 MB/s eta 0:00:01
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: pathspec<1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (0.7.0)
# Collecting jsonpickle<4.0.0
#   Downloading jsonpickle-3.2.1-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 606 kB/s eta 0:00:01
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 5.0 MB/s eta 0:00:01
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.1 MB/s eta 0:00:01
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.3.0-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (2.8.2)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: backports.tempfile in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (1.0)
# Requirement already satisfied: contextlib2<22.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (0.6.0.post1)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (21.0)
# Collecting knack<0.12.0
#   Downloading knack-0.11.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 10.6 MB/s eta 0:00:01
# Collecting azure-mgmt-storage<=22.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-21.2.0-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 12.3 MB/s eta 0:00:01
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 7.5 MB/s eta 0:00:011
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.28.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 5.5 MB/s eta 0:00:01
# Collecting argcomplete<4
#   Downloading argcomplete-3.4.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.1 MB/s  eta 0:00:01
# Requirement already satisfied: pkginfo in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (1.7.1)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jmespath<2.0.0
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 5.6 MB/s eta 0:00:01
# Collecting docker<8.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: pyopenssl<25.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (21.0.0)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (2.26.0)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.6 MB/s eta 0:00:01
# Collecting paramiko<4.0.0,>=2.0.8
#   Downloading paramiko-3.4.0-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 5.5 MB/s eta 0:00:01
# Collecting msal-extensions<=2.0.0,>=0.3.0
#   Downloading msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Collecting urllib3<3.0.0,>1.26.17
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (2021.3)
# Collecting azure-mgmt-network<=26.0.0
#   Downloading azure_mgmt_network-25.4.0-py3-none-any.whl (614 kB)
#      |████████████████████████████████| 614 kB 14.3 MB/s eta 0:00:01
# Collecting azure-mgmt-resource<=24.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-23.1.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 8.0 MB/s eta 0:00:01
# Collecting azure-mgmt-authorization<5,>=0.40.0
#   Downloading azure_mgmt_authorization-4.0.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: PyJWT<3.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from azureml-core) (2.1.0)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.3.0-py3-none-any.whl (933 kB)
#      |████████████████████████████████| 933 kB 5.6 MB/s eta 0:00:01
# Requirement already satisfied: cryptography>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core) (3.4.8)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core) (1.16.0)
# Collecting typing-extensions>=4.6.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.3.2
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Collecting isodate<1.0.0,>=0.6.1
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 991 kB/s eta 0:00:011
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (1.14.6)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (2.20)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.9/site-packages (from knack<0.12.0->azureml-core) (2.10.0)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.9/site-packages (from knack<0.12.0->azureml-core) (6.0)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2021.10.8)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from ndg-httpsclient<=0.5.1->azureml-core) (0.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging<=25.0,>=20.0->azureml-core) (3.0.4)
# Collecting bcrypt>=3.2
#   Downloading bcrypt-4.1.3-cp39-abi3-macosx_10_12_universal2.whl (506 kB)
#      |████████████████████████████████| 506 kB 8.4 MB/s eta 0:00:01
# Collecting pynacl>=1.5
#   Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
#      |████████████████████████████████| 349 kB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (2.0.4)
# Collecting urllib3<3.0.0,>1.26.17
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#      |████████████████████████████████| 143 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core) (3.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (1.7.1)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.1 MB/s eta 0:00:011
# Requirement already satisfied: backports.weakref in /opt/anaconda3/lib/python3.9/site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Installing collected packages: urllib3, typing-extensions, isodate, azure-core, msrest, adal, tabulate, pynacl, portalocker, msrestazure, msal, jmespath, jeepney, bcrypt, azure-mgmt-core, azure-common, argcomplete, SecretStorage, paramiko, ndg-httpsclient, msal-extensions, knack, jsonpickle, humanfriendly, docker, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-network, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, azureml-core
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.7
#     Uninstalling urllib3-1.26.7:
#       Successfully uninstalled urllib3-1.26.7
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed SecretStorage-3.3.3 adal-1.2.7 argcomplete-3.4.0 azure-common-1.1.28 azure-core-1.30.2 azure-graphrbac-0.61.1 azure-mgmt-authorization-4.0.0 azure-mgmt-containerregistry-10.3.0 azure-mgmt-core-1.4.0 azure-mgmt-keyvault-10.3.0 azure-mgmt-network-25.4.0 azure-mgmt-resource-23.1.1 azure-mgmt-storage-21.2.0 azureml-core-1.56.0 bcrypt-4.1.3 docker-7.1.0 humanfriendly-10.0 isodate-0.6.1 jeepney-0.8.0 jmespath-1.0.1 jsonpickle-3.2.1 knack-0.11.0 msal-1.28.1 msal-extensions-1.1.0 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 paramiko-3.4.0 portalocker-2.8.2 pynacl-1.5.0 tabulate-0.9.0 typing-extensions-4.12.2 urllib3-1.26.19
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.4.0
# adal                               1.2.7
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.4.2
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argcomplete                        3.4.0
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# azure-common                       1.1.28
# azure-core                         1.30.2
# azure-graphrbac                    0.61.1
# azure-mgmt-authorization           4.0.0
# azure-mgmt-containerregistry       10.3.0
# azure-mgmt-core                    1.4.0
# azure-mgmt-keyvault                10.3.0
# azure-mgmt-network                 25.4.0
# azure-mgmt-resource                23.1.1
# azure-mgmt-storage                 21.2.0
# azureml                            0.2.7
# azureml-core                       1.56.0
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             4.1.3
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         5.3.1
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.12.0
# conda-build                        3.21.5
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.10.0
# docker                             7.1.0
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        23.5.26
# fonttools                          4.25.0
# fsspec                             2021.8.1
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        2.22.0
# google-auth-oauthlib               1.0.0
# google-pasta                       0.2.0
# greenlet                           1.1.1
# grpcio                             1.57.0
# h5py                               3.2.1
# HeapDict                           1.0.1
# html5lib                           1.1
# humanfriendly                      10.0
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isodate                            0.6.1
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# jeepney                            0.8.0
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# jmespath                           1.0.1
# joblib                             1.1.0
# json5                              0.9.6
# jsonpickle                         3.2.1
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keras                              2.13.1
# keyring                            23.1.0
# kiwisolver                         1.3.1
# knack                              0.11.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           16.0.6
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.4.4
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msal                               1.28.1
# msal-extensions                    1.1.0
# msgpack                            1.0.2
# msrest                             0.7.1
# msrestazure                        0.6.4
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# ndg-httpsclient                    0.5.1
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.24.3
# numpydoc                           1.1.0
# oauthlib                           3.2.2
# olefile                            0.46
# openpyxl                           3.0.9
# opt-einsum                         3.3.0
# packaging                          21.0
# pandas                             1.3.4
# pandocfilters                      1.4.3
# paramiko                           3.4.0
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# portalocker                        2.8.2
# poyo                               0.5.0
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# protobuf                           4.24.2
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyasn1                             0.5.0
# pyasn1-modules                     0.3.0
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydocstyle                         6.1.1
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# PyNaCl                             1.5.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytz                               2021.3
# PyWavelets                         1.1.1
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# regex                              2021.8.3
# requests                           2.26.0
# requests-oauthlib                  1.3.1
# rope                               0.19.0
# rsa                                4.9
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.100439
# scipy                              1.7.1
# seaborn                            0.11.2
# SecretStorage                      3.3.3
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# statsmodels                        0.12.2
# sympy                              1.9
# tables                             3.6.1
# tabulate                           0.9.0
# TBB                                0.2
# tblib                              1.7.0
# tensorboard                        2.13.0
# tensorboard-data-server            0.7.1
# tensorflow                         2.13.0
# tensorflow-estimator               2.13.0
# tensorflow-io-gcs-filesystem       0.33.0
# termcolor                          2.3.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# typed-ast                          1.4.3
# typing_extensions                  4.12.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.19
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           2.0.2
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import azureml.core
print(azureml.core.VERSION)
# Out:
# 1.56.0

# %%
from azureml.core import Run
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Get the experiment run context
run = Run.get_context()

# Prepare the dataset
diabetes = pd.read_csv('diabetes_ml.csv')
X, y = diabetes[['Feature1','Feature2','Feature3']].values, diabetes['Label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# Train a logistic regression model
reg = 0.1
model = LogisticRegression(C=1/reg, solver="liblinear").fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
run.log('Accuracy', np.float(acc))

# Save the trained model
os.makedirs('outputs', exist_ok=True)
joblib.dump(value=model, filename='outputs/model.pkl')

run.complete()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/hr/5q0970ss4sx8g5dh2hp9mpgh0000gn/T/ipykernel_86444/2985851174.py in <module>
#      10
#      11 # Prepare the dataset
# ---> 12 diabetes = pd.read_csv('diabetes_ml.csv')
#      13 X, y = diabetes[['Feature1','Feature2','Feature3']].values, diabetes['Label'].values
#      14 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'diabetes_ml.csv'

# %%
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Get the experiment run context
run = Run.get_context()

# Set regularization hyperparameter
parser = argparse.ArgumentParser()
parser.add_argument('--reg-rate', type=float, dest='reg_rate', default=0.01)
args = parser.parse_args()
reg = args.reg_rate

# Prepare the dataset
diabetes = pd.read_csv('data.csv')
X, y = data[['Feature1','Feature2','Feature3']].values, data['Label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# Train a logistic regression model
model = LogisticRegression(C=1/reg, solver="liblinear").fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
run.log('Accuracy', np.float(acc))

# Save the trained model
os.makedirs('outputs', exist_ok=True)
joblib.dump(value=model, filename='outputs/model.pkl')

run.complete()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/hr/5q0970ss4sx8g5dh2hp9mpgh0000gn/T/ipykernel_86444/3336826205.py in <module>
# ----> 1 from azureml.core import Run
#       2 import argparse
#       3 import pandas as pd
#       4 import numpy as np
#       5 import joblib
#
# ModuleNotFoundError: No module named 'azureml'

# %%
from azureml.core import Run

# %%
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Get the experiment run context
run = Run.get_context()

# Set regularization hyperparameter
parser = argparse.ArgumentParser()
parser.add_argument('--reg-rate', type=float, dest='reg_rate', default=0.01)
args = parser.parse_args()
reg = args.reg_rate
# Out:
# usage: ipykernel_launcher.py [-h] [--reg-rate REG_RATE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /Users/joabodera/Library/Jupyter/runtime/kernel-14a939b9-0e08-44b0-b7b1-0db8db4adeff.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
